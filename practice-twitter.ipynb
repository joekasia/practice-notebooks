# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('Project/tweets.csv')

# %%
year2012 = len(df[df['Year'] == 2012])
year2013 = len(df[df['Year'] == 2013])
year2014 = len(df[df['Year'] == 2014])
year2015 = len(df[df['Year'] == 2015])
year2016 = len(df[df['Year'] == 2016])
year2017 = len(df[df['Year'] == 2017])

# %%
tweetcount = np.array([year2012, year2013, year2014, year2015, year2016, year2017])
years_total = np.array([2012, 2013, 2014, 2015, 2016, 2017])

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(years_total, tweetcount)
plt.title("Tweets by Year")
plt.xlabel("Year")
plt.ylabel("Tweet Count")
# Out:
# Text(0, 0.5, 'Tweet Count')

# %%
years_active = [year2012, year2013, year2014, year2015, year2016, year2017]
np.mean(years_active)
# Out:
# 190.16666666666666

# %%
plt.bar(years_total, tweetcount)
plt.title("Tweets by Year")
plt.xlabel("Year")
plt.ylabel("Tweet Count")
# Out:
# Text(0, 0.5, 'Tweet Count')

# %%
# plt.hist(years_total, bins=6)
